# %% [markdown]
# # Example Notebook
#
# This notebook is shared between Jupyter and Code Server.
#
# ## Folder Structure
# - `/code/dags/` - Airflow DAGs
# - `/code/dagster/` - Dagster pipelines
# - `/code/prefect/` - Prefect flows
# - `/code/notebooks/` - Jupyter notebooks
# - `/code/libs/` - Shared Python libraries

# %%
# Import shared libraries
import sys
sys.path.insert(0, '/home/jovyan/code/libs')

from libs import get_db_connection_string
print(get_db_connection_string())

# %%
# Example: Connect to PostgreSQL
# import pandas as pd
# import sqlalchemy
# 
# engine = sqlalchemy.create_engine(get_db_connection_string())
# df = pd.read_sql('SELECT 1 as test', engine)
# df
